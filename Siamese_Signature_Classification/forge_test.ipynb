# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! ln -s /content/drive/My\ Drive/ /mydrive

# %%
# %cd /mydrive/bank_check_verif_yolov5/Siamese_Signature_Classification/
# Out:
# /content/drive/My Drive/bank_check_verif_yolov5/Siamese_Signature_Classification

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
from PIL import Image
import PIL.ImageOps    
import pandas as pd
import os


import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Dataset
import torchvision.utils
import torch
from torch.autograd import Variable
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

# %%
def imshow(img,text=None,should_save=False):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()    

def show_plot(iteration,loss):
    plt.plot(iteration,loss)
    plt.show()

# %%
# First, look at everything.
from subprocess import check_output
print(check_output(["ls", "sign_data"]).decode("utf8"))
# Out:
# test
# test_data.csv
# train
# train_data.csv

# %%
class Config():
    training_dir = "sign_data/train"
    testing_dir = "sign_data/test"
    train_batch_size = 32
    train_number_epochs = 150

# %%
training_dir="sign_data/train"
training_csv="sign_data/train_data.csv"
testing_csv="sign_data/test_data.csv"
testing_dir="sign_data/test"

# %%
class SiameseNetworkDataset():
    
    def __init__(self,training_csv=None,training_dir=None,transform=None):
        # used to prepare the labels and images path
        self.training_df=pd.read_csv(training_csv)
        self.training_df.columns =["image1","image2","label"]
        self.training_dir = training_dir    
        self.transform = transform

    def __getitem__(self,index):
        
        # getting the image path
        image1_path=os.path.join(self.training_dir,self.training_df.iat[index,0])
        image2_path=os.path.join(self.training_dir,self.training_df.iat[index,1])
        
        
        # Loading the image
        img0 = Image.open(image1_path)
        img1 = Image.open(image2_path)
        img0 = img0.convert("L")
        img1 = img1.convert("L")
        
        # Apply image transformations
        if self.transform is not None:
            img0 = self.transform(img0)
            img1 = self.transform(img1)
        
        return img0, img1 , torch.from_numpy(np.array([int(self.training_df.iat[index,2])],dtype=np.float32))
    
    def __len__(self):
        return len(self.training_df)

# %%
# Load the the dataset from raw image folders
siamese_dataset = SiameseNetworkDataset(training_csv,training_dir,
                                        transform=transforms.Compose([transforms.Resize((100,100)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       )

# %%
# Viewing the sample of images and to check whether its loading properly
vis_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        batch_size=8)
dataiter = iter(vis_dataloader)


example_batch = next(dataiter)
concatenated = torch.cat((example_batch[0],example_batch[1]),0)
imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy())
# Out:
# [[1.]
#  [0.]
#  [0.]
#  [1.]
#  [1.]
#  [0.]
#  [1.]
#  [0.]]

# %%
class SiameseNetwork(nn.Module):

    def __init__(self):
        super(SiameseNetwork, self).__init__()

        self.conv1 = nn.Conv2d(1, 50, kernel_size=5)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        # L1 ImgIn shape=(?, 28, 28, 1)      # (n-f+2*p/s)+1
        #    Conv     -> (?, 24, 24, 50)
        #    Pool     -> (?, 12, 12, 50)

        self.conv2 = nn.Conv2d(50, 60, kernel_size=5)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        # L2 ImgIn shape=(?, 12, 12, 50)
        #    Conv      ->(?, 8, 8, 60)
        #    Pool      ->(?, 4, 4, 60)

        self.conv3 = nn.Conv2d(60, 80, kernel_size=3)
        # L3 ImgIn shape=(?, 4, 4, 60)
        #    Conv      ->(?, 2, 2, 80)

        self.batch_norm1 = nn.BatchNorm2d(50)
        self.batch_norm2 = nn.BatchNorm2d(60)

        #         self.dropout1 = nn.Dropout2d()

        # L4 FC 2*2*80 inputs -> 250 outputs
        self.fc1 = nn.Linear(32000, 128)
        self.fc2 = nn.Linear(128, 2)

    def forward1(self, x):
        x = self.conv1(x)
        x = self.batch_norm1(x)
        x = F.relu(x)
        x = self.pool1(x)

        x = self.conv2(x)
        x = self.batch_norm2(x)
        x = F.relu(x)
        x = self.pool2(x)

        x = self.conv3(x)
        x = F.relu(x)
        #         print(x.size())
        x = x.view(x.size()[0], -1)
        #         print('Output2')
        #         print(x.size()) #32000 thats why the input of fully connected layer is 32000
        x = F.relu(self.fc1(x))
        x = self.fc2(x)

        return x

    def forward(self, input1, input2):
        # forward pass of input 1
        output1 = self.forward1(input1)
        # forward pass of input 2
        output2 = self.forward1(input2)

        return output1, output2

# %%
# Define the Contrastive Loss Function
class ContrastiveLoss(torch.nn.Module):
    def __init__(self, margin=2.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
      # Calculate the euclidian distance and calculate the contrastive loss
      euclidean_distance = F.pairwise_distance(output1, output2, keepdim = True)

      loss_contrastive = torch.mean((1-label) * torch.pow(euclidean_distance, 2) +
                                    (label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2))


      return loss_contrastive

# %%
# Load the training dataset
train_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=8,
                        batch_size=64)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
net = SiameseNetwork().cuda()
criterion = ContrastiveLoss()
optimizer = optim.Adam(net.parameters(), lr = 0.0005 )

# %%
counter = []
loss_history = [] 
iteration_number= 0

# Iterate throught the epochs
for epoch in range(25):

    # Iterate over batches
    for i, (img0, img1, label) in enumerate(train_dataloader, 0):

        # Send the images and labels to CUDA
        img0, img1, label = img0.cuda(), img1.cuda(), label.cuda()

        # Zero the gradients
        optimizer.zero_grad()

        # Pass in the two images into the network and obtain two outputs
        output1, output2 = net(img0, img1)

        # Pass the outputs of the networks and label into the loss function
        loss_contrastive = criterion(output1, output2, label)

        # Calculate the backpropagation
        loss_contrastive.backward()

        # Optimize
        optimizer.step()

        # Every 10 batches print out the loss
        if i % 10 == 0 :
            print(f"Epoch number {epoch}\n Current loss {loss_contrastive.item()}\n")
            iteration_number += 10

            counter.append(iteration_number)
            loss_history.append(loss_contrastive.item())

show_plot(counter, loss_history)
# Out:
# Epoch number 0
#  Current loss 2.000934362411499
#
# Epoch number 0
#  Current loss 0.862991213798523
#
# Epoch number 0
#  Current loss 1.041014313697815
#
# Epoch number 0
#  Current loss 0.8526706695556641
#
# Epoch number 0
#  Current loss 0.45679864287376404
#
# Epoch number 0
#  Current loss 0.6456694006919861
#
# Epoch number 0
#  Current loss 0.5542254447937012
#
# Epoch number 0
#  Current loss 0.5521448850631714
#
# Epoch number 0
#  Current loss 0.4182843863964081
#
# Epoch number 0
#  Current loss 0.3706173300743103
#
# Epoch number 0
#  Current loss 0.2604925036430359
#
# Epoch number 0
#  Current loss 0.3340938091278076
#
# Epoch number 0
#  Current loss 0.36860811710357666
#
# Epoch number 0
#  Current loss 0.25727415084838867
#
# Epoch number 0
#  Current loss 0.18716669082641602
#
# Epoch number 0
#  Current loss 0.22663378715515137
#
# Epoch number 0
#  Current loss 0.17726629972457886
#
# Epoch number 0
#  Current loss 0.22598659992218018
#
# Epoch number 0
#  Current loss 0.18954813480377197
#
# Epoch number 0
#  Current loss 0.13846595585346222
#
# Epoch number 0
#  Current loss 0.18250182271003723
#
# Epoch number 0
#  Current loss 0.09845437854528427
#
# Epoch number 0
#  Current loss 0.1089891642332077
#
# Epoch number 0
#  Current loss 0.1354195475578308
#
# Epoch number 0
#  Current loss 0.06950633972883224
#
# Epoch number 0
#  Current loss 0.06373302638530731
#
# Epoch number 0
#  Current loss 0.06931886821985245
#
# Epoch number 0
#  Current loss 0.06149869039654732
#
# Epoch number 0
#  Current loss 0.05948570370674133
#
# Epoch number 0
#  Current loss 0.08060391992330551
#
# Epoch number 0
#  Current loss 0.07661216706037521
#
# Epoch number 0
#  Current loss 0.07135962694883347
#
# Epoch number 0
#  Current loss 0.05534528195858002
#
# Epoch number 0
#  Current loss 0.04524683952331543
#
# Epoch number 0
#  Current loss 0.06817735731601715
#
# Epoch number 0
#  Current loss 0.031480543315410614
#
# Epoch number 0
#  Current loss 0.05853018909692764
#
# Epoch number 1
#  Current loss 0.03502887487411499
#
# Epoch number 1
#  Current loss 0.03554248437285423
#
# Epoch number 1
#  Current loss 0.023884709924459457
#
# Epoch number 1
#  Current loss 0.09393228590488434
#
# Epoch number 1
#  Current loss 0.031805023550987244
#
# Epoch number 1
#  Current loss 0.03234729543328285
#
# Epoch number 1
#  Current loss 0.026634056121110916
#
# Epoch number 1
#  Current loss 0.023702923208475113
#
# Epoch number 1
#  Current loss 0.028775658458471298
#
# Epoch number 1
#  Current loss 0.02946673147380352
#
# Epoch number 1
#  Current loss 0.015619106590747833
#
# Epoch number 1
#  Current loss 0.027364280074834824
#
# Epoch number 1
#  Current loss 0.02232429012656212
#
# Epoch number 1
#  Current loss 0.024227168411016464
#
# Epoch number 1
#  Current loss 0.025772174820303917
#
# Epoch number 1
#  Current loss 0.024243921041488647
#
# Epoch number 1
#  Current loss 0.018017461523413658
#
# Epoch number 1
#  Current loss 0.021278295665979385
#
# Epoch number 1
#  Current loss 0.02617592364549637
#
# Epoch number 1
#  Current loss 0.023218953981995583
#
# Epoch number 1
#  Current loss 0.022033339366316795
#
# Epoch number 1
#  Current loss 0.024986542761325836
#
# Epoch number 1
#  Current loss 0.028745979070663452
#
# Epoch number 1
#  Current loss 0.018344741314649582
#
# Epoch number 1
#  Current loss 0.03058498352766037
#
# Epoch number 1
#  Current loss 0.036212995648384094
#
# Epoch number 1
#  Current loss 0.02126675471663475
#
# Epoch number 1
#  Current loss 0.031849250197410583
#
# Epoch number 1
#  Current loss 0.017643289640545845
#
# Epoch number 1
#  Current loss 0.014059404842555523
#
# Epoch number 1
#  Current loss 0.016202084720134735
#
# Epoch number 1
#  Current loss 0.01596716046333313
#
# Epoch number 1
#  Current loss 0.014872392639517784
#
# Epoch number 1
#  Current loss 0.023431221023201942
#
# Epoch number 1
#  Current loss 0.02460114285349846
#
# Epoch number 1
#  Current loss 0.01456763967871666
#
# Epoch number 1
#  Current loss 0.018880324438214302
#
# Epoch number 2
#  Current loss 0.013086480088531971
#
# Epoch number 2
#  Current loss 0.023757703602313995
#
# Epoch number 2
#  Current loss 0.02682749181985855
#
# Epoch number 2
#  Current loss 0.018769845366477966
#
# Epoch number 2
#  Current loss 0.03079323098063469
#
# Epoch number 2
#  Current loss 0.019079968333244324
#
# Epoch number 2
#  Current loss 0.017178377136588097
#
# Epoch number 2
#  Current loss 0.017747601494193077
#
# Epoch number 2
#  Current loss 0.020157549530267715
#
# Epoch number 2
#  Current loss 0.019757991656661034
#
# Epoch number 2
#  Current loss 0.021554123610258102
#
# Epoch number 2
#  Current loss 0.015348328277468681
#
# Epoch number 2
#  Current loss 0.014170634560286999
#
# Epoch number 2
#  Current loss 0.01832357794046402
#
# Epoch number 2
#  Current loss 0.02253887802362442
#
# Epoch number 2
#  Current loss 0.01916813850402832
#
# Epoch number 2
#  Current loss 0.01684914529323578
#
# Epoch number 2
#  Current loss 0.013085261918604374
#
# Epoch number 2
#  Current loss 0.02044588513672352
#
# Epoch number 2
#  Current loss 0.013039723969995975
#
# Epoch number 2
#  Current loss 0.017500393092632294
#
# Epoch number 2
#  Current loss 0.019153710454702377
#
# Epoch number 2
#  Current loss 0.01210695132613182
#
# Epoch number 2
#  Current loss 0.021844547241926193
#
# Epoch number 2
#  Current loss 0.0332304909825325
#
# Epoch number 2
#  Current loss 0.018910769373178482
#
# Epoch number 2
#  Current loss 0.016101228073239326
#
# Epoch number 2
#  Current loss 0.017343519255518913
#
# Epoch number 2
#  Current loss 0.01744147017598152
#
# Epoch number 2
#  Current loss 0.01642259955406189
#
# Epoch number 2
#  Current loss 0.021589839830994606
#
# Epoch number 2
#  Current loss 0.015339015051722527
#
# Epoch number 2
#  Current loss 0.02138909511268139
#
# Epoch number 2
#  Current loss 0.015239233151078224
#
# Epoch number 2
#  Current loss 0.012959502637386322
#
# Epoch number 2
#  Current loss 0.02574637159705162
#
# Epoch number 2
#  Current loss 0.01835610345005989
#
# Epoch number 3
#  Current loss 0.020549865439534187
#
# Epoch number 3
#  Current loss 0.01692487671971321
#
# Epoch number 3
#  Current loss 0.01579204574227333
#
# Epoch number 3
#  Current loss 0.013492968864738941
#
# Epoch number 3
#  Current loss 0.020009800791740417
#
# Epoch number 3
#  Current loss 0.014564313925802708
#
# Epoch number 3
#  Current loss 0.011363166384398937
#
# Epoch number 3
#  Current loss 0.020093828439712524
#
# Epoch number 3
#  Current loss 0.01274380274116993
#
# Epoch number 3
#  Current loss 0.015951618552207947
#
# Epoch number 3
#  Current loss 0.012953121215105057
#
# Epoch number 3
#  Current loss 0.019812943413853645
#
# Epoch number 3
#  Current loss 0.016394097357988358
#
# Epoch number 3
#  Current loss 0.011715519241988659
#
# Epoch number 3
#  Current loss 0.012025000527501106
#
# Epoch number 3
#  Current loss 0.010440142825245857
#
# Epoch number 3
#  Current loss 0.017237037420272827
#
# Epoch number 3
#  Current loss 0.012281261384487152
#
# Epoch number 3
#  Current loss 0.012043808586895466
#
# Epoch number 3
#  Current loss 0.00806985329836607
#
# Epoch number 3
#  Current loss 0.017264526337385178
#
# Epoch number 3
#  Current loss 0.02077607996761799
#
# Epoch number 3
#  Current loss 0.01697949878871441
#
# Epoch number 3
#  Current loss 0.006215725094079971
#
# Epoch number 3
#  Current loss 0.01918850839138031
#
# Epoch number 3
#  Current loss 0.011896580457687378
#
# Epoch number 3
#  Current loss 0.013758942484855652
#
# Epoch number 3
#  Current loss 0.018311144784092903
#
# Epoch number 3
#  Current loss 0.00851898081600666
#
# Epoch number 3
#  Current loss 0.02241557091474533
#
# Epoch number 3
#  Current loss 0.016292691230773926
#
# Epoch number 3
#  Current loss 0.013727200217545033
#
# Epoch number 3
#  Current loss 0.014093817211687565
#
# Epoch number 3
#  Current loss 0.009415896609425545
#
# Epoch number 3
#  Current loss 0.008131874725222588
#
# Epoch number 3
#  Current loss 0.006541504990309477
#
# Epoch number 3
#  Current loss 0.007900447584688663
#
# Epoch number 4
#  Current loss 0.01356132235378027
#
# Epoch number 4
#  Current loss 0.007481379434466362
#
# Epoch number 4
#  Current loss 0.00899368617683649
#
# Epoch number 4
#  Current loss 0.00867370143532753
#
# Epoch number 4
#  Current loss 0.01579558663070202
#
# Epoch number 4
#  Current loss 0.021077536046504974
#
# Epoch number 4
#  Current loss 0.009549188427627087
#
# Epoch number 4
#  Current loss 0.016571104526519775
#
# Epoch number 4
#  Current loss 0.013474838808178902
#
# Epoch number 4
#  Current loss 0.010132571682333946
#
# Epoch number 4
#  Current loss 0.007697081193327904
#
# Epoch number 4
#  Current loss 0.010493581183254719
#
# Epoch number 4
#  Current loss 0.013205013237893581
#
# Epoch number 4
#  Current loss 0.0052408138290047646
#
# Epoch number 4
#  Current loss 0.006367915775626898
#
# Epoch number 4
#  Current loss 0.011926103383302689
#
# Epoch number 4
#  Current loss 0.011170217767357826
#
# Epoch number 4
#  Current loss 0.006876514758914709
#
# Epoch number 4
#  Current loss 0.011648224666714668
#
# Epoch number 4
#  Current loss 0.010192308574914932
#
# Epoch number 4
#  Current loss 0.010969070717692375
#
# Epoch number 4
#  Current loss 0.008997922763228416
#
# Epoch number 4
#  Current loss 0.006206980440765619
#
# Epoch number 4
#  Current loss 0.00849772710353136
#
# Epoch number 4
#  Current loss 0.0101487310603261
#
# Epoch number 4
#  Current loss 0.010727021843194962
#
# Epoch number 4
#  Current loss 0.011624151840806007
#
# Epoch number 4
#  Current loss 0.00796749722212553
#
# Epoch number 4
#  Current loss 0.007721071131527424
#
# Epoch number 4
#  Current loss 0.008551464416086674
#
# Epoch number 4
#  Current loss 0.010099062696099281
#
# Epoch number 4
#  Current loss 0.00897799152880907
#
# Epoch number 4
#  Current loss 0.00732024759054184
#
# Epoch number 4
#  Current loss 0.005213777534663677
#
# Epoch number 4
#  Current loss 0.008653039112687111
#
# Epoch number 4
#  Current loss 0.010373765602707863
#
# Epoch number 4
#  Current loss 0.01083696261048317
#
# Epoch number 5
#  Current loss 0.009305995889008045
#
# Epoch number 5
#  Current loss 0.011818135157227516
#
# Epoch number 5
#  Current loss 0.01191494520753622
#
# Epoch number 5
#  Current loss 0.006134822033345699
#
# Epoch number 5
#  Current loss 0.010512922890484333
#
# Epoch number 5
#  Current loss 0.006343310698866844
#
# Epoch number 5
#  Current loss 0.016385097056627274
#
# Epoch number 5
#  Current loss 0.01925594173371792
#
# Epoch number 5
#  Current loss 0.012625474482774734
#
# Epoch number 5
#  Current loss 0.020439159125089645
#
# Epoch number 5
#  Current loss 0.011152300052344799
#
# Epoch number 5
#  Current loss 0.014625987969338894
#
# Epoch number 5
#  Current loss 0.01245645247399807
#
# Epoch number 5
#  Current loss 0.010201431810855865
#
# Epoch number 5
#  Current loss 0.01403216365724802
#
# Epoch number 5
#  Current loss 0.01489262469112873
#
# Epoch number 5
#  Current loss 0.018681757152080536
#
# Epoch number 5
#  Current loss 0.010513754561543465
#
# Epoch number 5
#  Current loss 0.010013824328780174
#
# Epoch number 5
#  Current loss 0.009857214987277985
#
# Epoch number 5
#  Current loss 0.006210865918546915
#
# Epoch number 5
#  Current loss 0.013015639036893845
#
# Epoch number 5
#  Current loss 0.010808482766151428
#
# Epoch number 5
#  Current loss 0.01000550203025341
#
# Epoch number 5
#  Current loss 0.006628038361668587
#
# Epoch number 5
#  Current loss 0.007346758618950844
#
# Epoch number 5
#  Current loss 0.008817466907203197
#
# Epoch number 5
#  Current loss 0.00921562034636736
#
# Epoch number 5
#  Current loss 0.007721727713942528
#
# Epoch number 5
#  Current loss 0.011503652669489384
#
# Epoch number 5
#  Current loss 0.007237999700009823
#
# Epoch number 5
#  Current loss 0.014356859028339386
#
# Epoch number 5
#  Current loss 0.008798450231552124
#
# Epoch number 5
#  Current loss 0.009608592838048935
#
# Epoch number 5
#  Current loss 0.012424401007592678
#
# Epoch number 5
#  Current loss 0.009519674815237522
#
# Epoch number 5
#  Current loss 0.009377534501254559
#
# Epoch number 6
#  Current loss 0.006419445388019085
#
# Epoch number 6
#  Current loss 0.008645674213767052
#
# Epoch number 6
#  Current loss 0.008278883993625641
#
# Epoch number 6
#  Current loss 0.00862809456884861
#
# Epoch number 6
#  Current loss 0.007931036874651909
#
# Epoch number 6
#  Current loss 0.010556253604590893
#
# Epoch number 6
#  Current loss 0.012122606858611107
#
# Epoch number 6
#  Current loss 0.011854950338602066
#
# Epoch number 6
#  Current loss 0.012163713574409485
#
# Epoch number 6
#  Current loss 0.009774768725037575
#
# Epoch number 6
#  Current loss 0.013154708780348301
#
# Epoch number 6
#  Current loss 0.009242642670869827
#
# Epoch number 6
#  Current loss 0.009848596528172493
#
# Epoch number 6
#  Current loss 0.009932536631822586
#
# Epoch number 6
#  Current loss 0.011343182995915413
#
# Epoch number 6
#  Current loss 0.006379704922437668
#
# Epoch number 6
#  Current loss 0.00527312932536006
#
# Epoch number 6
#  Current loss 0.006933366414159536
#
# Epoch number 6
#  Current loss 0.008160023018717766
#
# Epoch number 6
#  Current loss 0.0063924361020326614
#
# Epoch number 6
#  Current loss 0.007237614598125219
#
# Epoch number 6
#  Current loss 0.008387653157114983
#
# Epoch number 6
#  Current loss 0.0064892955124378204
#
# Epoch number 6
#  Current loss 0.005635308567434549
#
# Epoch number 6
#  Current loss 0.00770821375772357
#
# Epoch number 6
#  Current loss 0.005281168036162853
#
# Epoch number 6
#  Current loss 0.006207601632922888
#
# Epoch number 6
#  Current loss 0.0064438204281032085
#
# Epoch number 6
#  Current loss 0.005828202702105045
#
# Epoch number 6
#  Current loss 0.004222475923597813
#
# Epoch number 6
#  Current loss 0.0077250199392437935
#
# Epoch number 6
#  Current loss 0.006302245892584324
#
# Epoch number 6
#  Current loss 0.00698617659509182
#
# Epoch number 6
#  Current loss 0.006995330564677715
#
# Epoch number 6
#  Current loss 0.003641620511189103
#
# Epoch number 6
#  Current loss 0.004251338075846434
#
# Epoch number 6
#  Current loss 0.006090778391808271
#
# Epoch number 7
#  Current loss 0.007962997071444988
#
# Epoch number 7
#  Current loss 0.005454711616039276
#
# Epoch number 7
#  Current loss 0.008407115936279297
#
# Epoch number 7
#  Current loss 0.008275236934423447
#
# Epoch number 7
#  Current loss 0.005078421905636787
#
# Epoch number 7
#  Current loss 0.006492359563708305
#
# Epoch number 7
#  Current loss 0.006369179580360651
#
# Epoch number 7
#  Current loss 0.0055778855457901955
#
# Epoch number 7
#  Current loss 0.005963733419775963
#
# Epoch number 7
#  Current loss 0.006999071687459946
#
# Epoch number 7
#  Current loss 0.006428181193768978
#
# Epoch number 7
#  Current loss 0.009248556569218636
#
# Epoch number 7
#  Current loss 0.012918442487716675
#
# Epoch number 7
#  Current loss 0.011283976025879383
#
# Epoch number 7
#  Current loss 0.007601568475365639
#
# Epoch number 7
#  Current loss 0.010193179361522198
#
# Epoch number 7
#  Current loss 0.009557737037539482
#
# Epoch number 7
#  Current loss 0.012093672528862953
#
# Epoch number 7
#  Current loss 0.007859094999730587
#
# Epoch number 7
#  Current loss 0.009676947258412838
#
# Epoch number 7
#  Current loss 0.00556582398712635
#
# Epoch number 7
#  Current loss 0.008787709288299084
#
# Epoch number 7
#  Current loss 0.008859772235155106
#
# Epoch number 7
#  Current loss 0.012015975080430508
#
# Epoch number 7
#  Current loss 0.011647354811429977
#
# Epoch number 7
#  Current loss 0.011427907273173332
#
# Epoch number 7
#  Current loss 0.01711082272231579
#
# Epoch number 7
#  Current loss 0.009106314741075039
#
# Epoch number 7
#  Current loss 0.006547408178448677
#
# Epoch number 7
#  Current loss 0.009653326123952866
#
# Epoch number 7
#  Current loss 0.004282255657017231
#
# Epoch number 7
#  Current loss 0.012578416615724564
#
# Epoch number 7
#  Current loss 0.011475283652544022
#
# Epoch number 7
#  Current loss 0.005599369294941425
#
# Epoch number 7
#  Current loss 0.007498137187212706
#
# Epoch number 7
#  Current loss 0.010817810893058777
#
# Epoch number 7
#  Current loss 0.005147823132574558
#
# Epoch number 8
#  Current loss 0.007513278163969517
#
# Epoch number 8
#  Current loss 0.006465444341301918
#
# Epoch number 8
#  Current loss 0.0048173270188272
#
# Epoch number 8
#  Current loss 0.007259698584675789
#
# Epoch number 8
#  Current loss 0.006126880645751953
#
# Epoch number 8
#  Current loss 0.011127438396215439
#
# Epoch number 8
#  Current loss 0.010952969081699848
#
# Epoch number 8
#  Current loss 0.006031613796949387
#
# Epoch number 8
#  Current loss 0.0071179987862706184
#
# Epoch number 8
#  Current loss 0.00543235894292593
#
# Epoch number 8
#  Current loss 0.009942608885467052
#
# Epoch number 8
#  Current loss 0.006329352036118507
#
# Epoch number 8
#  Current loss 0.006896455772221088
#
# Epoch number 8
#  Current loss 0.00543958181515336
#
# Epoch number 8
#  Current loss 0.005103281699120998
#
# Epoch number 8
#  Current loss 0.00737479142844677
#
# Epoch number 8
#  Current loss 0.00456785736605525
#
# Epoch number 8
#  Current loss 0.006092661991715431
#
# Epoch number 8
#  Current loss 0.006181997247040272
#
# Epoch number 8
#  Current loss 0.005369969177991152
#
# Epoch number 8
#  Current loss 0.004043976776301861
#
# Epoch number 8
#  Current loss 0.004795641638338566
#
# Epoch number 8
#  Current loss 0.0073573896661400795
#
# Epoch number 8
#  Current loss 0.006224077194929123
#
# Epoch number 8
#  Current loss 0.0032976928632706404
#
# Epoch number 8
#  Current loss 0.004032130353152752
#
# Epoch number 8
#  Current loss 0.004249756224453449
#
# Epoch number 8
#  Current loss 0.004912785720080137
#
# Epoch number 8
#  Current loss 0.005085287149995565
#
# Epoch number 8
#  Current loss 0.0069360570050776005
#
# Epoch number 8
#  Current loss 0.0035226717591285706
#
# Epoch number 8
#  Current loss 0.009303439408540726
#
# Epoch number 8
#  Current loss 0.005788254551589489
#
# Epoch number 8
#  Current loss 0.008657960221171379
#
# Epoch number 8
#  Current loss 0.008062224835157394
#
# Epoch number 8
#  Current loss 0.008895931765437126
#
# Epoch number 8
#  Current loss 0.0070999558083713055
#
# Epoch number 9
#  Current loss 0.003337015863507986
#
# Epoch number 9
#  Current loss 0.007014114875346422
#
# Epoch number 9
#  Current loss 0.004305987618863583
#
# Epoch number 9
#  Current loss 0.007278278470039368
#
# Epoch number 9
#  Current loss 0.006032741628587246
#
# Epoch number 9
#  Current loss 0.004234325606375933
#
# Epoch number 9
#  Current loss 0.0038680052384734154
#
# Epoch number 9
#  Current loss 0.0037578875198960304
#
# Epoch number 9
#  Current loss 0.0042990450747311115
#
# Epoch number 9
#  Current loss 0.00367350853048265
#
# Epoch number 9
#  Current loss 0.0030485759489238262
#
# Epoch number 9
#  Current loss 0.0029254304245114326
#
# Epoch number 9
#  Current loss 0.0029108431190252304
#
# Epoch number 9
#  Current loss 0.0026975367218255997
#
# Epoch number 9
#  Current loss 0.003143430221825838
#
# Epoch number 9
#  Current loss 0.0039469534531235695
#
# Epoch number 9
#  Current loss 0.004374809563159943
#
# Epoch number 9
#  Current loss 0.004324536770582199
#
# Epoch number 9
#  Current loss 0.004006455652415752
#
# Epoch number 9
#  Current loss 0.004008757881820202
#
# Epoch number 9
#  Current loss 0.005896240007132292
#
# Epoch number 9
#  Current loss 0.003604362951591611
#
# Epoch number 9
#  Current loss 0.0032988442108035088
#
# Epoch number 9
#  Current loss 0.0027847150340676308
#
# Epoch number 9
#  Current loss 0.00476556271314621
#
# Epoch number 9
#  Current loss 0.0019958780612796545
#
# Epoch number 9
#  Current loss 0.003179196733981371
#
# Epoch number 9
#  Current loss 0.0019503837684169412
#
# Epoch number 9
#  Current loss 0.0018830486806109548
#
# Epoch number 9
#  Current loss 0.003558400319889188
#
# Epoch number 9
#  Current loss 0.0036488643381744623
#
# Epoch number 9
#  Current loss 0.0022968542762100697
#
# Epoch number 9
#  Current loss 0.0027486965991556644
#
# Epoch number 9
#  Current loss 0.004197623580694199
#
# Epoch number 9
#  Current loss 0.0023910689633339643
#
# Epoch number 9
#  Current loss 0.003836855525150895
#
# Epoch number 9
#  Current loss 0.003092414466664195
#
# Epoch number 10
#  Current loss 0.0032986397854983807
#
# Epoch number 10
#  Current loss 0.0039480035193264484
#
# Epoch number 10
#  Current loss 0.001875447342172265
#
# Epoch number 10
#  Current loss 0.004651698283851147
#
# Epoch number 10
#  Current loss 0.0023227278143167496
#
# Epoch number 10
#  Current loss 0.0027138786390423775
#
# Epoch number 10
#  Current loss 0.0020503175910562277
#
# Epoch number 10
#  Current loss 0.0031232922337949276
#
# Epoch number 10
#  Current loss 0.004080384038388729
#
# Epoch number 10
#  Current loss 0.00506722554564476
#
# Epoch number 10
#  Current loss 0.0024331773165613413
#
# Epoch number 10
#  Current loss 0.003759142477065325
#
# Epoch number 10
#  Current loss 0.001661014393903315
#
# Epoch number 10
#  Current loss 0.003697409760206938
#
# Epoch number 10
#  Current loss 0.0040046656504273415
#
# Epoch number 10
#  Current loss 0.004758266732096672
#
# Epoch number 10
#  Current loss 0.003994945902377367
#
# Epoch number 10
#  Current loss 0.0031198994256556034
#
# Epoch number 10
#  Current loss 0.004533391445875168
#
# Epoch number 10
#  Current loss 0.0039065126329660416
#
# Epoch number 10
#  Current loss 0.006007774267345667
#
# Epoch number 10
#  Current loss 0.0048105427995324135
#
# Epoch number 10
#  Current loss 0.010049010626971722
#
# Epoch number 10
#  Current loss 0.009865397587418556
#
# Epoch number 10
#  Current loss 0.009268427267670631
#
# Epoch number 10
#  Current loss 0.00675343070179224
#
# Epoch number 10
#  Current loss 0.0284316074103117
#
# Epoch number 10
#  Current loss 0.02047930657863617
#
# Epoch number 10
#  Current loss 0.02519204653799534
#
# Epoch number 10
#  Current loss 0.013973910361528397
#
# Epoch number 10
#  Current loss 0.02288993075489998
#
# Epoch number 10
#  Current loss 0.012567780911922455
#
# Epoch number 10
#  Current loss 0.012437701225280762
#
# Epoch number 10
#  Current loss 0.014243857935070992
#
# Epoch number 10
#  Current loss 0.010965247638523579
#
# Epoch number 10
#  Current loss 0.013125365599989891
#
# Epoch number 10
#  Current loss 0.015367912128567696
#
# Epoch number 11
#  Current loss 0.0083303926512599
#
# Epoch number 11
#  Current loss 0.005790695082396269
#
# Epoch number 11
#  Current loss 0.012314238585531712
#
# Epoch number 11
#  Current loss 0.011225476861000061
#
# Epoch number 11
#  Current loss 0.007364287972450256
#
# Epoch number 11
#  Current loss 0.010218007490038872
#
# Epoch number 11
#  Current loss 0.0046295225620269775
#
# Epoch number 11
#  Current loss 0.004479353316128254
#
# Epoch number 11
#  Current loss 0.0028283046558499336
#
# Epoch number 11
#  Current loss 0.004346108995378017
#
# Epoch number 11
#  Current loss 0.0027585262432694435
#
# Epoch number 11
#  Current loss 0.006066005676984787
#
# Epoch number 11
#  Current loss 0.0053977034986019135
#
# Epoch number 11
#  Current loss 0.004341464955359697
#
# Epoch number 11
#  Current loss 0.003112882375717163
#
# Epoch number 11
#  Current loss 0.0032299552112817764
#
# Epoch number 11
#  Current loss 0.004137270152568817
#
# Epoch number 11
#  Current loss 0.0023751286789774895
#
# Epoch number 11
#  Current loss 0.002009293530136347
#
# Epoch number 11
#  Current loss 0.003864297177642584
#
# Epoch number 11
#  Current loss 0.0016243967693299055
#
# Epoch number 11
#  Current loss 0.002938605612143874
#
# Epoch number 11
#  Current loss 0.0014741471968591213
#
# Epoch number 11
#  Current loss 0.0026180464774370193
#
# Epoch number 11
#  Current loss 0.00238104653544724
#
# Epoch number 11
#  Current loss 0.001913502812385559
#
# Epoch number 11
#  Current loss 0.001851952401921153
#
# Epoch number 11
#  Current loss 0.0018424454610794783
#
# Epoch number 11
#  Current loss 0.0017180076101794839
#
# Epoch number 11
#  Current loss 0.0014477565418928862
#
# Epoch number 11
#  Current loss 0.0036395974457263947
#
# Epoch number 11
#  Current loss 0.0018879798008129
#
# Epoch number 11
#  Current loss 0.001717257546260953
#
# Epoch number 11
#  Current loss 0.0033530208747833967
#
# Epoch number 11
#  Current loss 0.0018542981706559658
#
# Epoch number 11
#  Current loss 0.0014045999851077795
#
# Epoch number 11
#  Current loss 0.003215888049453497
#
# Epoch number 12
#  Current loss 0.002060976345092058
#
# Epoch number 12
#  Current loss 0.0014991173520684242
#
# Epoch number 12
#  Current loss 0.0025601089000701904
#
# Epoch number 12
#  Current loss 0.0020841159857809544
#
# Epoch number 12
#  Current loss 0.0013451233971863985
#
# Epoch number 12
#  Current loss 0.0013895889278501272
#
# Epoch number 12
#  Current loss 0.0022198972292244434
#
# Epoch number 12
#  Current loss 0.0011310585541650653
#
# Epoch number 12
#  Current loss 0.0018549920059740543
#
# Epoch number 12
#  Current loss 0.0015971034299582243
#
# Epoch number 12
#  Current loss 0.0016347633209079504
#
# Epoch number 12
#  Current loss 0.0011167303891852498
#
# Epoch number 12
#  Current loss 0.0005839435616508126
#
# Epoch number 12
#  Current loss 0.000649662921205163
#
# Epoch number 12
#  Current loss 0.0014595817774534225
#
# Epoch number 12
#  Current loss 0.0008136649848893285
#
# Epoch number 12
#  Current loss 0.001006745733320713
#
# Epoch number 12
#  Current loss 0.0006687066052109003
#
# Epoch number 12
#  Current loss 0.001593050081282854
#
# Epoch number 12
#  Current loss 0.002809430006891489
#
# Epoch number 12
#  Current loss 0.0009761810069903731
#
# Epoch number 12
#  Current loss 0.0011800983920693398
#
# Epoch number 12
#  Current loss 0.0014594990061596036
#
# Epoch number 12
#  Current loss 0.0012514148838818073
#
# Epoch number 12
#  Current loss 0.0015276677440851927
#
# Epoch number 12
#  Current loss 0.001573180896230042
#
# Epoch number 12
#  Current loss 0.0013852035626769066
#
# Epoch number 12
#  Current loss 0.0013785456540063024
#
# Epoch number 12
#  Current loss 0.0011669197119772434
#
# Epoch number 12
#  Current loss 0.0015800558030605316
#
# Epoch number 12
#  Current loss 0.001214619493111968
#
# Epoch number 12
#  Current loss 0.0009686105186119676
#
# Epoch number 12
#  Current loss 0.0009250444127246737
#
# Epoch number 12
#  Current loss 0.0011875638738274574
#
# Epoch number 12
#  Current loss 0.0008192759705707431
#
# Epoch number 12
#  Current loss 0.0009353180066682398
#
# Epoch number 12
#  Current loss 0.0007398654124699533
#
# Epoch number 13
#  Current loss 0.0009627328254282475
#
# Epoch number 13
#  Current loss 0.0027237185277044773
#
# Epoch number 13
#  Current loss 0.0024271132424473763
#
# Epoch number 13
#  Current loss 0.0011646448401734233
#
# Epoch number 13
#  Current loss 0.001015261746942997
#
# Epoch number 13
#  Current loss 0.0007285157917067409
#
# Epoch number 13
#  Current loss 0.0008888880256563425
#
# Epoch number 13
#  Current loss 0.0009884277824312449
#
# Epoch number 13
#  Current loss 0.0008930005133152008
#
# Epoch number 13
#  Current loss 0.0009902386227622628
#
# Epoch number 13
#  Current loss 0.001174894510768354
#
# Epoch number 13
#  Current loss 0.001681824680417776
#
# Epoch number 13
#  Current loss 0.001627645455300808
#
# Epoch number 13
#  Current loss 0.004433081950992346
#
# Epoch number 13
#  Current loss 0.007247375324368477
#
# Epoch number 13
#  Current loss 0.017168806865811348
#
# Epoch number 13
#  Current loss 0.020321335643529892
#
# Epoch number 13
#  Current loss 0.018091825768351555
#
# Epoch number 13
#  Current loss 0.01849513128399849
#
# Epoch number 13
#  Current loss 0.029086289927363396
#
# Epoch number 13
#  Current loss 0.015488455072045326
#
# Epoch number 13
#  Current loss 0.0329417884349823
#
# Epoch number 13
#  Current loss 0.03141181543469429
#
# Epoch number 13
#  Current loss 0.028002755716443062
#
# Epoch number 13
#  Current loss 0.05341009423136711
#
# Epoch number 13
#  Current loss 0.03001173958182335
#
# Epoch number 13
#  Current loss 0.05523814260959625
#
# Epoch number 13
#  Current loss 0.02171924337744713
#
# Epoch number 13
#  Current loss 0.016875606030225754
#
# Epoch number 13
#  Current loss 0.015163727104663849
#
# Epoch number 13
#  Current loss 0.030859682708978653
#
# Epoch number 13
#  Current loss 0.058865658938884735
#
# Epoch number 13
#  Current loss 0.022465955466032028
#
# Epoch number 13
#  Current loss 0.024163374677300453
#
# Epoch number 13
#  Current loss 0.031770892441272736
#
# Epoch number 13
#  Current loss 0.04756568372249603
#
# Epoch number 13
#  Current loss 0.02387547492980957
#
# Epoch number 14
#  Current loss 0.0194027628749609
#
# Epoch number 14
#  Current loss 0.01831791177392006
#
# Epoch number 14
#  Current loss 0.011866171844303608
#
# Epoch number 14
#  Current loss 0.006702050566673279
#
# Epoch number 14
#  Current loss 0.005855606868863106
#
# Epoch number 14
#  Current loss 0.003334718756377697
#
# Epoch number 14
#  Current loss 0.004487777594476938
#
# Epoch number 14
#  Current loss 0.005127820186316967
#
# Epoch number 14
#  Current loss 0.0018432820215821266
#
# Epoch number 14
#  Current loss 0.002586559858173132
#
# Epoch number 14
#  Current loss 0.005580340512096882
#
# Epoch number 14
#  Current loss 0.0024099545553326607
#
# Epoch number 14
#  Current loss 0.0016012652777135372
#
# Epoch number 14
#  Current loss 0.00293623935431242
#
# Epoch number 14
#  Current loss 0.0022785968612879515
#
# Epoch number 14
#  Current loss 0.0014720363542437553
#
# Epoch number 14
#  Current loss 0.0013181664980947971
#
# Epoch number 14
#  Current loss 0.0014068237505853176
#
# Epoch number 14
#  Current loss 0.002195791807025671
#
# Epoch number 14
#  Current loss 0.0017658747965469956
#
# Epoch number 14
#  Current loss 0.0016975117614492774
#
# Epoch number 14
#  Current loss 0.0007681568386033177
#
# Epoch number 14
#  Current loss 0.0007186445873230696
#
# Epoch number 14
#  Current loss 0.0005580773577094078
#
# Epoch number 14
#  Current loss 0.0011414815671741962
#
# Epoch number 14
#  Current loss 0.0005156274419277906
#
# Epoch number 14
#  Current loss 0.0011661486933007836
#
# Epoch number 14
#  Current loss 0.0004603852576110512
#
# Epoch number 14
#  Current loss 0.0006203984376043081
#
# Epoch number 14
#  Current loss 0.00055102095939219
#
# Epoch number 14
#  Current loss 0.001390813384205103
#
# Epoch number 14
#  Current loss 0.0011690047103911638
#
# Epoch number 14
#  Current loss 0.0005097849061712623
#
# Epoch number 14
#  Current loss 0.0008777669863775373
#
# Epoch number 14
#  Current loss 0.0005879552336409688
#
# Epoch number 14
#  Current loss 0.0005381944356486201
#
# Epoch number 14
#  Current loss 0.0004945494583807886
#
# Epoch number 15
#  Current loss 0.0003342203563079238
#
# Epoch number 15
#  Current loss 0.0008522671996615827
#
# Epoch number 15
#  Current loss 0.0006738284137099981
#
# Epoch number 15
#  Current loss 0.0006047124625183642
#
# Epoch number 15
#  Current loss 0.0007429806864820421
#
# Epoch number 15
#  Current loss 0.00040859225555323064
#
# Epoch number 15
#  Current loss 0.0005690790130756795
#
# Epoch number 15
#  Current loss 0.000575290818233043
#
# Epoch number 15
#  Current loss 0.0005538571276701987
#
# Epoch number 15
#  Current loss 0.00046263629337772727
#
# Epoch number 15
#  Current loss 0.0003927682409994304
#
# Epoch number 15
#  Current loss 0.0007699151174165308
#
# Epoch number 15
#  Current loss 0.0005823513492941856
#
# Epoch number 15
#  Current loss 0.0003691205056384206
#
# Epoch number 15
#  Current loss 0.0003982856869697571
#
# Epoch number 15
#  Current loss 0.0009835995733737946
#
# Epoch number 15
#  Current loss 0.00043040799209848046
#
# Epoch number 15
#  Current loss 0.0005379451904445887
#
# Epoch number 15
#  Current loss 0.0004329227958805859
#
# Epoch number 15
#  Current loss 0.0005399963119998574
#
# Epoch number 15
#  Current loss 0.0005859946249984205
#
# Epoch number 15
#  Current loss 0.00037566182436421514
#
# Epoch number 15
#  Current loss 0.0006765405414626002
#
# Epoch number 15
#  Current loss 0.0007539751240983605
#
# Epoch number 15
#  Current loss 0.0012351407203823328
#
# Epoch number 15
#  Current loss 0.000559091626200825
#
# Epoch number 15
#  Current loss 0.0005802115774713457
#
# Epoch number 15
#  Current loss 0.00033219161559827626
#
# Epoch number 15
#  Current loss 0.00041904556564986706
#
# Epoch number 15
#  Current loss 0.00040034300764091313
#
# Epoch number 15
#  Current loss 0.0002849330485332757
#
# Epoch number 15
#  Current loss 0.0004492287407629192
#
# Epoch number 15
#  Current loss 0.0005076138768345118
#
# Epoch number 15
#  Current loss 0.0003927776706404984
#
# Epoch number 15
#  Current loss 0.0004367775109130889
#
# Epoch number 15
#  Current loss 0.00034753140062093735
#
# Epoch number 15
#  Current loss 0.0005281282356008887
#
# Epoch number 16
#  Current loss 0.00041568875894881785
#
# Epoch number 16
#  Current loss 0.0008162996964529157
#
# Epoch number 16
#  Current loss 0.000725907739251852
#
# Epoch number 16
#  Current loss 0.0004931009607389569
#
# Epoch number 16
#  Current loss 0.00042331282747909427
#
# Epoch number 16
#  Current loss 0.0013047333341091871
#
# Epoch number 16
#  Current loss 0.0005402606911957264
#
# Epoch number 16
#  Current loss 0.0005719405598938465
#
# Epoch number 16
#  Current loss 0.0003778001992031932
#
# Epoch number 16
#  Current loss 0.0014611430233344436
#
# Epoch number 16
#  Current loss 0.0005580458091571927
#
# Epoch number 16
#  Current loss 0.0012221857905387878
#
# Epoch number 16
#  Current loss 0.001354368170723319
#
# Epoch number 16
#  Current loss 0.0007829328533262014
#
# Epoch number 16
#  Current loss 0.0006721944082528353
#
# Epoch number 16
#  Current loss 0.0009327892912551761
#
# Epoch number 16
#  Current loss 0.0006381316343322396
#
# Epoch number 16
#  Current loss 0.00034195405896753073
#
# Epoch number 16
#  Current loss 0.0005926212179474533
#
# Epoch number 16
#  Current loss 0.0008702562190592289
#
# Epoch number 16
#  Current loss 0.0008234628476202488
#
# Epoch number 16
#  Current loss 0.0005437401123344898
#
# Epoch number 16
#  Current loss 0.0005591758526861668
#
# Epoch number 16
#  Current loss 0.0028275514487177134
#
# Epoch number 16
#  Current loss 0.0006616265163756907
#
# Epoch number 16
#  Current loss 0.0004669396730605513
#
# Epoch number 16
#  Current loss 0.0005223539192229509
#
# Epoch number 16
#  Current loss 0.0004695422248914838
#
# Epoch number 16
#  Current loss 0.00041144437273032963
#
# Epoch number 16
#  Current loss 0.0003704405389726162
#
# Epoch number 16
#  Current loss 0.00043969659600406885
#
# Epoch number 16
#  Current loss 0.0009330674656666815
#
# Epoch number 16
#  Current loss 0.0007418869063258171
#
# Epoch number 16
#  Current loss 0.0004938083584420383
#
# Epoch number 16
#  Current loss 0.0004822021583095193
#
# Epoch number 16
#  Current loss 0.0004994716728106141
#
# Epoch number 16
#  Current loss 0.000931466172914952
#
# Epoch number 17
#  Current loss 0.0005934262881055474
#
# Epoch number 17
#  Current loss 0.0005614079418592155
#
# Epoch number 17
#  Current loss 0.00038955855416134
#
# Epoch number 17
#  Current loss 0.00048053357750177383
#
# Epoch number 17
#  Current loss 0.0005889058229513466
#
# Epoch number 17
#  Current loss 0.0004092369053978473
#
# Epoch number 17
#  Current loss 0.0004263452719897032
#
# Epoch number 17
#  Current loss 0.00043385429307818413
#
# Epoch number 17
#  Current loss 0.000298051571007818
#
# Epoch number 17
#  Current loss 0.00031677301740273833
#
# Epoch number 17
#  Current loss 0.000255612627370283
#
# Epoch number 17
#  Current loss 0.0003741909167729318
#
# Epoch number 17
#  Current loss 0.0005232672556303442
#
# Epoch number 17
#  Current loss 0.0003607451799325645
#
# Epoch number 17
#  Current loss 0.000621139770373702
#
# Epoch number 17
#  Current loss 0.00043709762394428253
#
# Epoch number 17
#  Current loss 0.0005620952579192817
#
# Epoch number 17
#  Current loss 0.0004793274274561554
#
# Epoch number 17
#  Current loss 0.0004811609978787601
#
# Epoch number 17
#  Current loss 0.00021589630341622978
#
# Epoch number 17
#  Current loss 0.00023008330026641488
#
# Epoch number 17
#  Current loss 0.000489664264023304
#
# Epoch number 17
#  Current loss 0.00040093756979331374
#
# Epoch number 17
#  Current loss 0.00034279271494597197
#
# Epoch number 17
#  Current loss 0.00029934459598734975
#
# Epoch number 17
#  Current loss 0.0006014596438035369
#
# Epoch number 17
#  Current loss 0.00034940335899591446
#
# Epoch number 17
#  Current loss 0.00033333362080156803
#
# Epoch number 17
#  Current loss 0.0002651484392117709
#
# Epoch number 17
#  Current loss 0.0004430906556081027
#
# Epoch number 17
#  Current loss 0.0004274632956366986
#
# Epoch number 17
#  Current loss 0.0008897139923647046
#
# Epoch number 17
#  Current loss 0.00039106415351852775
#
# Epoch number 17
#  Current loss 0.0005463070701807737
#
# Epoch number 17
#  Current loss 0.0002405551786068827
#
# Epoch number 17
#  Current loss 0.0006837389664724469
#
# Epoch number 17
#  Current loss 0.0005061932024545968
#
# Epoch number 18
#  Current loss 0.0006002852460369468
#
# Epoch number 18
#  Current loss 0.000348878325894475
#
# Epoch number 18
#  Current loss 0.0009177489555440843
#
# Epoch number 18
#  Current loss 0.0009371802443638444
#
# Epoch number 18
#  Current loss 0.0004153845366090536
#
# Epoch number 18
#  Current loss 0.0007284049643203616
#
# Epoch number 18
#  Current loss 0.0010543729877099395
#
# Epoch number 18
#  Current loss 0.0005513355135917664
#
# Epoch number 18
#  Current loss 0.0006696664495393634
#
# Epoch number 18
#  Current loss 0.00031713047064840794
#
# Epoch number 18
#  Current loss 0.0006793452193960547
#
# Epoch number 18
#  Current loss 0.000731864245608449
#
# Epoch number 18
#  Current loss 0.0010362636530771852
#
# Epoch number 18
#  Current loss 0.0007127018761821091
#
# Epoch number 18
#  Current loss 0.0007427252130582929
#
# Epoch number 18
#  Current loss 0.0007183357374742627
#
# Epoch number 18
#  Current loss 0.0014502817066386342
#
# Epoch number 18
#  Current loss 0.0007294833194464445
#
# Epoch number 18
#  Current loss 0.0005582325393334031
#
# Epoch number 18
#  Current loss 0.0006439226563088596
#
# Epoch number 18
#  Current loss 0.000852837460115552
#
# Epoch number 18
#  Current loss 0.0005591405788436532
#
# Epoch number 18
#  Current loss 0.0005357782356441021
#
# Epoch number 18
#  Current loss 0.0005146108451299369
#
# Epoch number 18
#  Current loss 0.0016235464718192816
#
# Epoch number 18
#  Current loss 0.0005923300050199032
#
# Epoch number 18
#  Current loss 0.00044017346226610243
#
# Epoch number 18
#  Current loss 0.0004947230918332934
#
# Epoch number 18
#  Current loss 0.0004533812461886555
#
# Epoch number 18
#  Current loss 0.0018770766910165548
#
# Epoch number 18
#  Current loss 0.00047922690282575786
#
# Epoch number 18
#  Current loss 0.0004632633354049176
#
# Epoch number 18
#  Current loss 0.0002842057147063315
#
# Epoch number 18
#  Current loss 0.0008832454914227128
#
# Epoch number 18
#  Current loss 0.00034856388811022043
#
# Epoch number 18
#  Current loss 0.0007804236374795437
#
# Epoch number 18
#  Current loss 0.000379307777620852
#
# Epoch number 19
#  Current loss 0.000939416466280818
#
# Epoch number 19
#  Current loss 0.00039009767351672053
#
# Epoch number 19
#  Current loss 0.00043710783938877285
#
# Epoch number 19
#  Current loss 0.0006017133127897978
#
# Epoch number 19
#  Current loss 0.0006190227577462792
#
# Epoch number 19
#  Current loss 0.0004823184572160244
#
# Epoch number 19
#  Current loss 0.0006403150036931038
#
# Epoch number 19
#  Current loss 0.0017837052000686526
#
# Epoch number 19
#  Current loss 0.000453494256362319
#
# Epoch number 19
#  Current loss 0.00037471274845302105
#
# Epoch number 19
#  Current loss 0.0006330444011837244
#
# Epoch number 19
#  Current loss 0.0005271648406051099
#
# Epoch number 19
#  Current loss 0.0003847713232971728
#
# Epoch number 19
#  Current loss 0.0008011823520064354
#
# Epoch number 19
#  Current loss 0.0013146891724318266
#
# Epoch number 19
#  Current loss 0.0026924200356006622
#
# Epoch number 19
#  Current loss 0.009034710004925728
#
# Epoch number 19
#  Current loss 0.006831557489931583
#
# Epoch number 19
#  Current loss 0.01245366781949997
#
# Epoch number 19
#  Current loss 0.024703647941350937
#
# Epoch number 19
#  Current loss 0.01153484731912613
#
# Epoch number 19
#  Current loss 0.03505020961165428
#
# Epoch number 19
#  Current loss 0.016827180981636047
#
# Epoch number 19
#  Current loss 0.03425799310207367
#
# Epoch number 19
#  Current loss 0.019220605492591858
#
# Epoch number 19
#  Current loss 0.015984315425157547
#
# Epoch number 19
#  Current loss 0.012438113801181316
#
# Epoch number 19
#  Current loss 0.008147815242409706
#
# Epoch number 19
#  Current loss 0.013828618451952934
#
# Epoch number 19
#  Current loss 0.013109726831316948
#
# Epoch number 19
#  Current loss 0.005503119435161352
#
# Epoch number 19
#  Current loss 0.00811002217233181
#
# Epoch number 19
#  Current loss 0.004744945093989372
#
# Epoch number 19
#  Current loss 0.006483552046120167
#
# Epoch number 19
#  Current loss 0.0019342121668159962
#
# Epoch number 19
#  Current loss 0.005267707630991936
#
# Epoch number 19
#  Current loss 0.0017162752337753773
#
# Epoch number 20
#  Current loss 0.006157746072858572
#
# Epoch number 20
#  Current loss 0.003326068166643381
#
# Epoch number 20
#  Current loss 0.005246695131063461
#
# Epoch number 20
#  Current loss 0.0030382522381842136
#
# Epoch number 20
#  Current loss 0.003212996292859316
#
# Epoch number 20
#  Current loss 0.0040161870419979095
#
# Epoch number 20
#  Current loss 0.0016927348915487528
#
# Epoch number 20
#  Current loss 0.0023907788563519716
#
# Epoch number 20
#  Current loss 0.0034298687241971493
#
# Epoch number 20
#  Current loss 0.001081322319805622
#
# Epoch number 20
#  Current loss 0.0019051535055041313
#
# Epoch number 20
#  Current loss 0.0009832368232309818
#
# Epoch number 20
#  Current loss 0.0006961122853681445
#
# Epoch number 20
#  Current loss 0.0010668236063793302
#
# Epoch number 20
#  Current loss 0.000926541571971029
#
# Epoch number 20
#  Current loss 0.0008153222734108567
#
# Epoch number 20
#  Current loss 0.0006119280587881804
#
# Epoch number 20
#  Current loss 0.0006334245554171503
#
# Epoch number 20
#  Current loss 0.0004209154867567122
#
# Epoch number 20
#  Current loss 0.0004369080124888569
#
# Epoch number 20
#  Current loss 0.000456294568721205
#
# Epoch number 20
#  Current loss 0.00022661192633677274
#
# Epoch number 20
#  Current loss 0.00043087825179100037
#
# Epoch number 20
#  Current loss 0.0006747607258148491
#
# Epoch number 20
#  Current loss 0.0003239523502998054
#
# Epoch number 20
#  Current loss 0.00022606350830756128
#
# Epoch number 20
#  Current loss 0.00035122717963531613
#
# Epoch number 20
#  Current loss 0.0007117220666259527
#
# Epoch number 20
#  Current loss 0.0004106354608666152
#
# Epoch number 20
#  Current loss 0.0005223551415838301
#
# Epoch number 20
#  Current loss 0.00039722034125588834
#
# Epoch number 20
#  Current loss 0.00025517510948702693
#
# Epoch number 20
#  Current loss 0.0001713485107757151
#
# Epoch number 20
#  Current loss 0.00035854519228450954
#
# Epoch number 20
#  Current loss 0.00029580286354757845
#
# Epoch number 20
#  Current loss 0.00035126929287798703
#
# Epoch number 20
#  Current loss 0.0003246106789447367
#
# Epoch number 21
#  Current loss 0.0005249831010587513
#
# Epoch number 21
#  Current loss 0.0004741815209854394
#
# Epoch number 21
#  Current loss 0.00035500689409673214
#
# Epoch number 21
#  Current loss 0.00020162937289569527
#
# Epoch number 21
#  Current loss 0.00046313475468195975
#
# Epoch number 21
#  Current loss 0.00030605008942075074
#
# Epoch number 21
#  Current loss 0.0005001162062399089
#
# Epoch number 21
#  Current loss 0.000591177144087851
#
# Epoch number 21
#  Current loss 0.00024363143893424422
#
# Epoch number 21
#  Current loss 0.0002145754697266966
#
# Epoch number 21
#  Current loss 0.0002726643579080701
#
# Epoch number 21
#  Current loss 0.00031780058634467423
#
# Epoch number 21
#  Current loss 0.00023324116773437709
#
# Epoch number 21
#  Current loss 0.0003043796168640256
#
# Epoch number 21
#  Current loss 0.00014151391224004328
#
# Epoch number 21
#  Current loss 0.0002794782049022615
#
# Epoch number 21
#  Current loss 0.00010828445374500006
#
# Epoch number 21
#  Current loss 0.0002250681136501953
#
# Epoch number 21
#  Current loss 0.0002423547557555139
#
# Epoch number 21
#  Current loss 0.00015952247485984117
#
# Epoch number 21
#  Current loss 0.00014241240569390357
#
# Epoch number 21
#  Current loss 0.00039767142152413726
#
# Epoch number 21
#  Current loss 0.000333963253069669
#
# Epoch number 21
#  Current loss 0.0001990408927667886
#
# Epoch number 21
#  Current loss 0.00022575230104848742
#
# Epoch number 21
#  Current loss 0.0006089885137043893
#
# Epoch number 21
#  Current loss 0.0004282947920728475
#
# Epoch number 21
#  Current loss 0.000305166351608932
#
# Epoch number 21
#  Current loss 0.00024509610375389457
#
# Epoch number 21
#  Current loss 0.0002766637480817735
#
# Epoch number 21
#  Current loss 0.00042646221118047833
#
# Epoch number 21
#  Current loss 0.0002761313517112285
#
# Epoch number 21
#  Current loss 0.00026475050253793597
#
# Epoch number 21
#  Current loss 0.0002470663166604936
#
# Epoch number 21
#  Current loss 0.0005308390827849507
#
# Epoch number 21
#  Current loss 0.000247990625211969
#
# Epoch number 21
#  Current loss 0.0008323865476995707
#
# Epoch number 22
#  Current loss 0.0002602972381282598
#
# Epoch number 22
#  Current loss 0.0002557103580329567
#
# Epoch number 22
#  Current loss 0.00029076854116283357
#
# Epoch number 22
#  Current loss 0.000352097034920007
#
# Epoch number 22
#  Current loss 0.00032725109485909343
#
# Epoch number 22
#  Current loss 0.0003595672606024891
#
# Epoch number 22
#  Current loss 0.000167821446666494
#
# Epoch number 22
#  Current loss 0.00016314489766955376
#
# Epoch number 22
#  Current loss 0.00017923497944138944
#
# Epoch number 22
#  Current loss 0.0001610580802662298
#
# Epoch number 22
#  Current loss 0.00014537264360114932
#
# Epoch number 22
#  Current loss 0.0002859148080460727
#
# Epoch number 22
#  Current loss 0.00021343515254557133
#
# Epoch number 22
#  Current loss 0.00021600298350676894
#
# Epoch number 22
#  Current loss 0.00013099992065690458
#
# Epoch number 22
#  Current loss 0.0004478656919673085
#
# Epoch number 22
#  Current loss 0.00046347640454769135
#
# Epoch number 22
#  Current loss 0.000188638165127486
#
# Epoch number 22
#  Current loss 0.000178200047230348
#
# Epoch number 22
#  Current loss 0.0003048368962481618
#
# Epoch number 22
#  Current loss 0.00017290961113758385
#
# Epoch number 22
#  Current loss 0.0003236865159124136
#
# Epoch number 22
#  Current loss 0.000169457052834332
#
# Epoch number 22
#  Current loss 0.00024153973208740354
#
# Epoch number 22
#  Current loss 0.0002494484360795468
#
# Epoch number 22
#  Current loss 0.00023710753885097802
#
# Epoch number 22
#  Current loss 0.0001546009734738618
#
# Epoch number 22
#  Current loss 0.00011666301725199446
#
# Epoch number 22
#  Current loss 0.00016870796389412135
#
# Epoch number 22
#  Current loss 0.0006468773353844881
#
# Epoch number 22
#  Current loss 0.0004386542132124305
#
# Epoch number 22
#  Current loss 0.0004248826880939305
#
# Epoch number 22
#  Current loss 0.00039837133954279125
#
# Epoch number 22
#  Current loss 0.00049165403470397
#
# Epoch number 22
#  Current loss 0.0002814130566548556
#
# Epoch number 22
#  Current loss 0.0007714368985034525
#
# Epoch number 22
#  Current loss 0.0006638442864641547
#
# Epoch number 23
#  Current loss 0.00047077302588149905
#
# Epoch number 23
#  Current loss 0.0027412320487201214
#
# Epoch number 23
#  Current loss 0.00040362344589084387
#
# Epoch number 23
#  Current loss 0.0003174375742673874
#
# Epoch number 23
#  Current loss 0.00038355542346835136
#
# Epoch number 23
#  Current loss 0.00043740481487475336
#
# Epoch number 23
#  Current loss 0.00041353510459885
#
# Epoch number 23
#  Current loss 0.00043442845344543457
#
# Epoch number 23
#  Current loss 0.0002990814973600209
#
# Epoch number 23
#  Current loss 0.0003358020621817559
#
# Epoch number 23
#  Current loss 0.0003108872042503208
#
# Epoch number 23
#  Current loss 0.0004567786236293614
#
# Epoch number 23
#  Current loss 0.00022915583394933492
#
# Epoch number 23
#  Current loss 0.0003284940030425787
#
# Epoch number 23
#  Current loss 0.00027327699353918433
#
# Epoch number 23
#  Current loss 0.00038815278094261885
#
# Epoch number 23
#  Current loss 0.000641548540443182
#
# Epoch number 23
#  Current loss 0.00029526586877182126
#
# Epoch number 23
#  Current loss 0.0003036439302377403
#
# Epoch number 23
#  Current loss 0.00013263702567201108
#
# Epoch number 23
#  Current loss 0.0005057431990280747
#
# Epoch number 23
#  Current loss 0.0006523742340505123
#
# Epoch number 23
#  Current loss 0.0005431738682091236
#
# Epoch number 23
#  Current loss 0.00020494117052294314
#
# Epoch number 23
#  Current loss 0.0003047279897145927
#
# Epoch number 23
#  Current loss 0.00014259203453548253
#
# Epoch number 23
#  Current loss 0.00015297964273486286
#
# Epoch number 23
#  Current loss 0.00016504342784173787
#
# Epoch number 23
#  Current loss 0.0003766397130675614
#
# Epoch number 23
#  Current loss 0.0005065631121397018
#
# Epoch number 23
#  Current loss 0.00035740266321226954
#
# Epoch number 23
#  Current loss 0.00027686823159456253
#
# Epoch number 23
#  Current loss 0.00040208420250564814
#
# Epoch number 23
#  Current loss 0.00011454472405603155
#
# Epoch number 23
#  Current loss 0.0002147365448763594
#
# Epoch number 23
#  Current loss 0.00019127887208014727
#
# Epoch number 23
#  Current loss 0.0003683373797684908
#
# Epoch number 24
#  Current loss 0.0002565939212217927
#
# Epoch number 24
#  Current loss 0.00028126020333729684
#
# Epoch number 24
#  Current loss 0.00039941153954714537
#
# Epoch number 24
#  Current loss 0.00021290878066793084
#
# Epoch number 24
#  Current loss 0.00023743468045722693
#
# Epoch number 24
#  Current loss 0.00017415822367183864
#
# Epoch number 24
#  Current loss 0.00024359652888961136
#
# Epoch number 24
#  Current loss 0.00040959639591164887
#
# Epoch number 24
#  Current loss 0.0005710545228794217
#
# Epoch number 24
#  Current loss 0.000521687907166779
#
# Epoch number 24
#  Current loss 0.0042984564788639545
#
# Epoch number 24
#  Current loss 0.018559787422418594
#
# Epoch number 24
#  Current loss 0.03276395797729492
#
# Epoch number 24
#  Current loss 0.06130291894078255
#
# Epoch number 24
#  Current loss 0.04201425611972809
#
# Epoch number 24
#  Current loss 0.10847049206495285
#
# Epoch number 24
#  Current loss 0.04916185140609741
#
# Epoch number 24
#  Current loss 0.027645565569400787
#
# Epoch number 24
#  Current loss 0.03151959180831909
#
# Epoch number 24
#  Current loss 0.02530500665307045
#
# Epoch number 24
#  Current loss 0.02619343437254429
#
# Epoch number 24
#  Current loss 0.016657207161188126
#
# Epoch number 24
#  Current loss 0.0112492386251688
#
# Epoch number 24
#  Current loss 0.018885653465986252
#
# Epoch number 24
#  Current loss 0.007332842331379652
#
# Epoch number 24
#  Current loss 0.010097114369273186
#
# Epoch number 24
#  Current loss 0.004593509715050459
#
# Epoch number 24
#  Current loss 0.0022990661673247814
#
# Epoch number 24
#  Current loss 0.004049928858876228
#
# Epoch number 24
#  Current loss 0.0022018253803253174
#
# Epoch number 24
#  Current loss 0.001071459730155766
#
# Epoch number 24
#  Current loss 0.0030753323808312416
#
# Epoch number 24
#  Current loss 0.0014193395618349314
#
# Epoch number 24
#  Current loss 0.0030614545103162527
#
# Epoch number 24
#  Current loss 0.0012876848923042417
#
# Epoch number 24
#  Current loss 0.001366000040434301
#
# Epoch number 24
#  Current loss 0.0006492654792964458

# %%
torch.save(net.state_dict(), "siamese.pt")
print("Model Saved Successfully")
# Out:
# Model Saved Successfully

# %%
# Load the saved model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SiameseNetwork().to(device)
model.load_state_dict(torch.load("siamese.pt"))
# Out:
# <All keys matched successfully>

# %%
test_dataset = SiameseNetworkDataset(training_csv=testing_csv,training_dir=testing_dir,
                                        transform=transforms.Compose([transforms.Resize((100,100)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       )

test_dataloader = DataLoader(test_dataset,num_workers=6,batch_size=1,shuffle=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
counter=0
list_0 = torch.FloatTensor([[0]])
list_1 = torch.FloatTensor([[1]])
for i, data in enumerate(test_dataloader,0): 
    x0, x1 , label = data
    concatenated = torch.cat((x0,x1),0)
    output1,output2 = model(x0.to(device),x1.to(device))
    eucledian_distance = F.pairwise_distance(output1, output2)
    if label==list_0:
        label="Orginial"
    else:
        label="Forged"
    imshow(torchvision.utils.make_grid(concatenated),'Dissimilarity: {:.2f} Label: {}'.format(eucledian_distance.item(),label))
    counter=counter+1
    if counter ==30:
        break

# %%
# Load the saved model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
mod = SiameseNetwork().to(device)
mod.load_state_dict(torch.load("m.pt"))
# Out:
# <All keys matched successfully>

# %%
counter=0
list_0 = torch.FloatTensor([[0]])
list_1 = torch.FloatTensor([[1]])
for i, data in enumerate(test_dataloader,0): 
    x0, x1 , label = data
    concatenated = torch.cat((x0,x1),0)
    output1,output2 = mod(x0.to(device),x1.to(device))
    eucledian_distance = F.pairwise_distance(output1, output2)
    if label==list_0:
        label="Orginial"
    else:
        label="Forged"
    imshow(torchvision.utils.make_grid(concatenated),'Dissimilarity: {:.2f} Label: {}'.format(eucledian_distance.item(),label))
    counter=counter+1
    if counter ==20:
        break
